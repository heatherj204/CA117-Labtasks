# %% [markdown]
# # Lecture 11.3 : Searching graphs (again)

# %% [markdown]
# ## Introduction
#
# - We present an approach to searching through a graph called
#   *breadth-first search*.
# - We previously saw that depth-first search (DFS) is a recursive
#   algorithm that uses back-tracking to identify and explore novel
#   paths.
# - An alternative to DFS is breadth-first search (BFS).
# - BFS does not use recursion but instead makes use of a queue.
# - BFS can be used to find all vertices connected to a given vertex.
# - BFS can be used to find a path betwen two vertices (should one exist).
# - Before we code it, let’s look at BFS in action so we can see how
#   it works.
# - [Here’s a video I made](https://drive.google.com/file/d/1Zy0xBUIj2bo3jFO6odEKPtRBIxc1-EXP/view?usp=sharing).
# - [Here’s a website with BFS animations](https://www.cs.usfca.edu/~galles/visualization/BFS.html).
# - [Here’s a website with lots of algorithm animations](https://visualgo.net/en).

# %% [markdown]
# ## Our graph
#
# ![graph01.png](data:image/png;base64,...)

# %% [markdown]
# ## Graph description
#
# - As usual, we describe a graph with a simple text file where the first line
# defines the number of vertices in the graph and the following lines define
# the edges (i.e. which vertices are connected to which).

# %% [markdown]
# ```text
# $ cat graph01.txt
# 7
# 0 1
# 0 2
# 0 5
# 0 6
# 3 4
# 3 5
# 4 5
# 4 6
# ```

# %%
# Let's create our text file
with open('graph01.txt', 'w') as f:
  f.write('7\n')
  f.write('0 1\n')
  f.write('0 2\n')
  f.write('0 5\n')
  f.write('0 6\n')
  f.write('3 4\n')
  f.write('3 5\n')
  f.write('4 5\n')
  f.write('4 6\n')

# %%
# !cat graph01.txt
# Out:
# 7
# 0 1
# 0 2
# 0 5
# 0 6
# 3 4
# 3 5
# 4 5
# 4 6

# %% [markdown]
# ## Basic graph class
#
# - Our basic graph class looks as follows.

# %%
# Our Graph class
class Graph(object):

  def __init__(self, V):
    self.V = V
    self.adj = {}
    for v in range(self.V):
      self.adj[v] = list() # []

  def addEdge(self, v, w):
    self.adj[v].append(w)
    self.adj[w].append(v)

# Initialise a Graph instance
with open('graph01.txt', 'r') as f:
  V = int(f.readline().strip())
  g = Graph(V)

  for line in f:
    v, w = [int(t) for t in line.strip().split()]
    g.addEdge(v, w)

print(g.V)
print(g.adj)
# Out:
# 7
# {0: [1, 2, 5, 6], 1: [0], 2: [0], 3: [4, 5], 4: [3, 5, 6], 5: [0, 3, 4], 6: [0, 4]}

# %% [markdown]
# ## Coding BFS
#
# - We will not add a new method to the `Graph` class but will instead
#   create a new `BFSPaths` class.
# - The input to the `BFSPaths` class is the graph we wish to explore
# using BFS and a starting vertex.

# %%
# TODO: Code the BFSPaths class
class BFSPath(object):
    def __init__(self, g ,s) -> None:
        self.g = g
        self.s = s
        # once queued a vertex is marked
        # initially none of the vertices have been marked
        # self.marked ==    todo
        # weneed to remember how we reached each vertex
        # self.parent = TODO

    def bfs(self, s):
        pass
        #we start at s
        # remember bfs is non-recursive and is quee-based
        # initialise our queue
        # queue = [s]
        # mark s as having been queued so we do not quese it again
        # TODO

        #while we have veertices to vissti
        # i.e. while the queue is non empty
        # TODO while
        # remove the vertex at the head of the quese
        # TODO
        # record how each was reached
        # TODO
        # mark it so we never queue it again
        # TODO

# %% [markdown]
# ## Applying BFS to a graph

# %%
# TODO: Apply BFS to our graph
# bfs = BFSPaths(g, 0)
# print(bfs.pathTo(6))
# print(bfs.pathTo(0))
# print(bfs.pathTo(4))
